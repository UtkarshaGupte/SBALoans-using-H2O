# %% [markdown]
# ## Dataset description
#
# ### Loans dataset
# The dataset is from the U.S. Small Business Administration (SBA) The U.S. SBA was founded in 1953 on the principle of promoting and assisting small enterprises in the U.S. credit market (SBA Overview and History, US Small Business Administration (2015)). Small businesses have been a primary source of job creation in the United States; therefore, fostering small business formation and growth has social benefits by creating job opportunities and reducing unemployment. There have been many success stories of start-ups receiving SBA loan guarantees such as FedEx and Apple Computer. However, there have also been stories of small businesses and/or start-ups that have defaulted on their SBA-guaranteed loans.
# More info on the original dataset: https://www.kaggle.com/mirbektoktogaraev/should-this-loan-be-approved-or-denied

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', 1500)

import warnings
warnings.filterwarnings('ignore')

#Extend cell width
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# <style>.container { width:80% !important; }</style>

# %%
"""
Created on Mon Mar 18 18:25:50 2019

@author: Uri Smashnov

Purpose: Analyze input Pandas DataFrame and return stats per column
Details: The function calculates levels for categorical variables and allows to analyze summarized information

To view wide table set following Pandas options:
pd.set_option('display.width', 1000)
pd.set_option('max_colwidth',200)
"""
import pandas as pd
def describe_more(df,normalize_ind=False, weight_column=None, skip_columns=[], dropna=True):
    var = [] ; l = [] ; t = []; unq =[]; min_l = []; max_l = [];
    assert isinstance(skip_columns, list), "Argument skip_columns should be list"
    if weight_column is not None:
        if weight_column not in list(df.columns):
            raise AssertionError('weight_column is not a valid column name in the input DataFrame')
      
    for x in df:
        if x in skip_columns:
            pass
        else:
            var.append( x )
            uniq_counts = len(pd.value_counts(df[x],dropna=dropna))
            uniq_counts = len(pd.value_counts(df[x], dropna=dropna)[pd.value_counts(df[x],dropna=dropna)>0])
            l.append(uniq_counts)
            t.append( df[ x ].dtypes )
            min_l.append(df[x].apply(str).str.len().min())
            max_l.append(df[x].apply(str).str.len().max())
            if weight_column is not None and x not in skip_columns:
                df2 = df.groupby(x).agg({weight_column: 'sum'}).sort_values(weight_column, ascending=False)
                df2['authtrans_vts_cnt']=((df2[weight_column])/df2[weight_column].sum()).round(2)
                unq.append(df2.head(n=100).to_dict()[weight_column])
            else:
                df_cat_d = df[x].value_counts(normalize=normalize_ind,dropna=dropna).round(decimals=2)
                df_cat_d = df_cat_d[df_cat_d>0]
                #unq.append(df[x].value_counts().iloc[0:100].to_dict())
                unq.append(df_cat_d.iloc[0:100].to_dict())
            
    levels = pd.DataFrame( { 'A_Variable' : var , 'Levels' : l , 'Datatype' : t ,
                             'Min Length' : min_l,
                             'Max Length': max_l,
                             'Level_Values' : unq} )
    #levels.sort_values( by = 'Levels' , inplace = True )
    return levels

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Load datasets

# %%
loans = pd.read_csv('./SBA_loans_project_2/SBA_loans_project_2.csv')

# %%
print("Data shape for loans dataset:", loans.shape)
# Out:
# Data shape for loans dataset: (809247, 19)

# %% [markdown]
# ### SBA Loans dataset

# %%
loans.head(n=3)
# Out:
#        City State    Zip                            Bank BankState   NAICS  \
# 0   BRADLEY    WV  25818     CITY NATL BK OF W. VIRGINIA        WV       0
# 1  LA JOLLA    CA  92037  U.S. BANK NATIONAL ASSOCIATION        OH  531210
# 2   WINSLOW    AZ  86047  SOUTHWESTERN BUS. FINANCING CO        AZ  721110
#
#    NoEmp  NewExist  CreateJob  RetainedJob  FranchiseCode  UrbanRural  \
# 0      7       1.0          0            0              1           0
# 1      1       2.0          0            1              0           1
# 2     30       1.0          0            1          10465           2
#
#   RevLineCr LowDoc DisbursementGross BalanceGross          GrAppv  \
# 0         N      Y       $30,000.00        $0.00      $30,000.00
# 1         Y      N       $50,000.00        $0.00      $50,000.00
# 2         0      N    $1,297,000.00        $0.00   $1,300,000.00
#
#          SBA_Appv MIS_Status
# 0     $27,000.00       P I F
# 1     $25,000.00       P I F
# 2  $1,300,000.00       P I F

# %% [markdown]
# ### Reviewing data

# %%
desc_loans_df = describe_more(loans)
desc_loans_df
# Out:
#            A_Variable  Levels Datatype  Min Length  Max Length  \
# 0                City   31289   object           1          30
# 1               State      51   object           2           3
# 2                 Zip   32740    int64           1           5
# 3                Bank    5699   object           3          30
# 4           BankState      56   object           2           3
# 5               NAICS    1309    int64           1           6
# 6               NoEmp     576    int64           1           4
# 7            NewExist       3  float64           3           3
# 8           CreateJob     232    int64           1           4
# 9         RetainedJob     347    int64           1           4
# 10      FranchiseCode    2685    int64           1           5
# 11         UrbanRural       3    int64           1           1
# 12          RevLineCr      18   object           1           3
# 13             LowDoc       8   object           1           3
# 14  DisbursementGross  110650   object           6          15
# 15       BalanceGross      15   object           6          12
# 16             GrAppv   20749   object           8          14
# 17           SBA_Appv   35956   object           8          14
# 18         MIS_Status       2   object           3           6
#
#                                          Level_Values
# 0   {'LOS ANGELES': 10421, 'HOUSTON': 9194, 'NEW Y...
# 1   {'CA': 117735, 'TX': 63313, 'NY': 52031, 'FL':...
# 2   {90015: 843, 10001: 823, 93401: 726, 90010: 66...
# 3   {'BANK OF AMERICA NATL ASSOC': 78119, 'WELLS F...
# 4   {'CA': 106451, 'NC': 71484, 'IL': 59292, 'OH':...
# 5   {0: 181606, 722110: 25266, 722211: 17505, 8111...
# 6   {1: 138747, 2: 124352, 3: 81499, 4: 66471, 5: ...
# 7                {1.0: 580544, 2.0: 227662, 0.0: 920}
# 8   {0: 566266, 1: 56838, 2: 52098, 3: 25928, 4: 1...
# 9   {0: 396245, 1: 79902, 2: 69113, 3: 44894, 4: 3...
# 10  {1: 574567, 0: 188154, 78760: 3043, 68020: 173...
# 11                   {1: 423475, 0: 290853, 2: 94919}
# 12  {'N': 378024, '0': 231849, 'Y': 181502, 'T': 1...
# 13  {'N': 704491, 'Y': 99348, '0': 1340, 'C': 689,...
# 14  {'$50,000.00 ': 39461, '$100,000.00 ': 33061, ...
# 15  {'$0.00 ': 809233, '$395,476.00 ': 1, '$9,111....
# 16  {'$50,000.00 ': 62633, '$25,000.00 ': 46149, '...
# 17  {'$25,000.00 ': 44810, '$12,500.00 ': 36149, '...
# 18                {'P I F': 665817, 'CHGOFF': 141634}

# %% [markdown]
# ### Dataset preparation and clean-up
#
# I modified and clean-up the dataset as following:
# - Replaced Na/Null values with missing/0 values except for the response column - MIS_Status
# - Then dropped the rows which had na values in response column after taking care of it for all other columns
# - Converted the strings styled as '$XXXX.XX' to float values. Columns = ['DisbursementGross', 'BalanceGross', 'GrAppv', 'SBA_Appv']
# - Converted MIS_Status to 0/1. Replaced value of 'CHGOFF' with 1 and 'P I F' with 0

# %% [markdown]
# ***Part 1: Replaced Na/Null values***

# %%
values_to_fill = {}
for col in loans.drop(columns=['MIS_Status']).columns:
    if loans[col].dtype == 'object':
        values_to_fill[col] = "Missing"
    else:
        values_to_fill[col] = 0

loans.fillna(value=values_to_fill,inplace=True)

# %%
for col in loans.columns:
    if loans[col].isna().any() == True:
        print("Column(s) with missing value(s) in SBA loans dataset is:", col, "of type" , loans[col].dtype.name)
# Out:
# Column(s) with missing value(s) in SBA loans dataset is: MIS_Status of type object

# %% [markdown]
# ***Part 2: Dropped rows with na value in the response column***

# %%
loans['MIS_Status'].unique()
# Out:
# array(['P I F', 'CHGOFF', nan], dtype=object)

# %%
len(loans[loans.isna().any(axis=1)]['MIS_Status'])
# Out:
# 1796

# %% [markdown]
# ##### There are 1796 records with nan values in MIS_Status column. We are going to drop those rows from the SBA loans dataset

# %%
loans = loans.dropna()

# %% [markdown]
# ***Part 3: Converted the strings styled as '$XXXX.XX' to float values. Columns = ['DisbursementGross', 'BalanceGross', 'GrAppv', 'SBA_Appv']***

# %%
col_toFloat = ['DisbursementGross', 'BalanceGross', 'GrAppv', 'SBA_Appv']

# %% [markdown]
# ##### Removed the extra spaces at the end of the string, removed the commas, removed the ' $' value from the values in those columns and then converted to Float

# %%
for col in col_toFloat:
    loans[col] = loans[col].apply(lambda x: (x.replace(' ','')))
    loans[col] = loans[col].apply(lambda x: (x.replace(',','')))
    loans[col] = loans[col].apply(lambda x: (x.replace('$','')))
    loans[col] = loans[col].astype(float)

# %%
loans[col_toFloat].dtypes
# Out:
# DisbursementGross    float64
# BalanceGross         float64
# GrAppv               float64
# SBA_Appv             float64
# dtype: object

# %% [markdown]
# ***Part 3: Converted MIS_Status to 0/1. Make value "CHGOFF" as 1***

# %%
loans['MIS_Status'] = loans['MIS_Status'].map({'P I F':0, 'CHGOFF':1}).astype(int)
loans['MIS_Status'].unique()
# Out:
# array([0, 1])

# %%
loans.head(n=3)
# Out:
#        City State    Zip                            Bank BankState   NAICS  \
# 0   BRADLEY    WV  25818     CITY NATL BK OF W. VIRGINIA        WV       0
# 1  LA JOLLA    CA  92037  U.S. BANK NATIONAL ASSOCIATION        OH  531210
# 2   WINSLOW    AZ  86047  SOUTHWESTERN BUS. FINANCING CO        AZ  721110
#
#    NoEmp  NewExist  CreateJob  RetainedJob  FranchiseCode  UrbanRural  \
# 0      7       1.0          0            0              1           0
# 1      1       2.0          0            1              0           1
# 2     30       1.0          0            1          10465           2
#
#   RevLineCr LowDoc  DisbursementGross  BalanceGross     GrAppv   SBA_Appv  \
# 0         N      Y            30000.0           0.0    30000.0    27000.0
# 1         Y      N            50000.0           0.0    50000.0    25000.0
# 2         0      N          1297000.0           0.0  1300000.0  1300000.0
#
#    MIS_Status
# 0           0
# 1           0
# 2           0

# %% [markdown]
# #### Feature Engineering
#
# I added below two new features to see if it helps the model with more information:
# - LoanDisbursedPerCity = Loan Disbursed to small businesses per city
# - LoanPaid = DisbursementGross - BalanceGross

# %%
loans['LoanDisbursedPerCity'] = loans.groupby('City')['DisbursementGross'].transform(np.sum)

# %%
loans['LoanPaid'] = loans['DisbursementGross'] - loans['BalanceGross']

# %% [markdown]
# **Categorical columns that needs to be encoded**

# %%
cols_to_encode = []
cat_encoders = {}
for col in loans.drop(columns=['MIS_Status']).columns:
    if loans[col].dtype == 'object':
        cols_to_encode.append(col)
    
#Add Zip to categoricals and convert to string in order to make encoder work
cols_to_encode.append("Zip")
loans["Zip"] = loans["Zip"].apply(str)

# %%
cols_to_encode
# Out:
# ['City', 'State', 'Bank', 'BankState', 'RevLineCr', 'LowDoc', 'Zip']

# %% [markdown]
# ## Opening H2O

# %%
#Extend cell width
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))

import warnings
warnings.filterwarnings('ignore')

import pandas as pd 

#Install shap package as needed:
#!pip uninstall numpy
#!pip uninstall numba
#!pip install shap==0.40.0

import shap

import h2o
from h2o.estimators import H2OTargetEncoderEstimator

try:
    h2o.cluster().shutdown()
except:
    pass
# Out:
# <style>.container { width:80% !important; }</style>

# %%
#Limit to 3 threads and 8GB memory
h2o.init(nthreads=3, max_mem_size=8)
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 ..... not found.
# Attempting to start a local H2O server...
# ; Java HotSpot(TM) 64-Bit Server VM 18.3 (build 10.0.2+13, mixed mode)
#   Starting server from C:\Users\General\Documents\UTD\Semester 3\Applied Machine Learning\VirtualMachine\ml-spring-2022\Lib\site-packages\h2o\backend\bin\h2o.jar
#   Ice root: C:\Users\General\AppData\Local\Temp\tmpftaptxrd
#   JVM stdout: C:\Users\General\AppData\Local\Temp\tmpftaptxrd\h2o_General_started_from_python.out
#   JVM stderr: C:\Users\General\AppData\Local\Temp\tmpftaptxrd\h2o_General_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# Warning: Your H2O cluster version is too old (4 months and 6 days)!Please download and install the latest version from http://h2o.ai/download/
# --------------------------  -------------------------------------------------------------------
# H2O_cluster_uptime:         03 secs
# H2O_cluster_timezone:       America/Los_Angeles
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.36.0.1
# H2O_cluster_version_age:    4 months and 6 days !!!
# H2O_cluster_name:           H2O_from_python_General_1x6yvg
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    8 Gb
# H2O_cluster_total_cores:    4
# H2O_cluster_allowed_cores:  3
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://127.0.0.1:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# H2O_API_Extensions:         Amazon S3, Algos, Infogram, AutoML, Core V3, TargetEncoder, Core V4
# Python_version:             3.8.10 final
# --------------------------  -------------------------------------------------------------------

# %% [markdown]
# **Splitting into train,test and validation dataset**
# - With 80% of the data in the training dataset
# - Remaining 20% split between testing and validation dataset
# - I also made use of stratify parameter to take care of imbalanced class dataset at hand
# - It made sure my training dataset have same ratio of 0/1 as in the original dataset

# %%
from sklearn.model_selection import train_test_split

# In the first step we will split the data in training and remaining dataset
loans_train, loans_test = train_test_split(loans, train_size=0.8, random_state=0, stratify=loans['MIS_Status'])

# In the second step we will split the data in test and validation dataset
loans_test, loans_valid = train_test_split(loans_test, train_size=0.5, random_state=0, stratify=loans_test['MIS_Status'])

# %%
print("Dimensions of train dataset: ",loans_train.shape)
print("Dimensions of test dataset: ",loans_test.shape)
print("Dimensions of validation dataset: ",loans_valid.shape)
# Out:
# Dimensions of train dataset:  (645960, 21)
# Dimensions of test dataset:  (80745, 21)
# Dimensions of validation dataset:  (80746, 21)

# %% [markdown]
# **Passing the cleaned up dataset with cleaning and manipulations I did in earlier steps to H2O**

# %%
loans_train = h2o.H2OFrame(loans_train)
loans_test = h2o.H2OFrame(loans_test)
loans_valid = h2o.H2OFrame(loans_valid)
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%

# %%
# Choose which columns to encode
cat_columns = ['City', 'State', 'Bank', 'BankState', 'RevLineCr', 'LowDoc', 'Zip', 'UrbanRural', 'FranchiseCode', 'NewExist']
response = "MIS_Status"

# %% [markdown]
# **Factoring the categorical columns in all the datasets**

# %%
loans_train[cat_columns+[response]] = loans_train[cat_columns+[response]].asfactor()
loans_test[cat_columns+[response]] = loans_test[cat_columns+[response]].asfactor()
loans_valid[cat_columns+[response]] = loans_valid[cat_columns+[response]].asfactor()

# %% [markdown]
# ## Categorical variables encoding

# %% [markdown]
# ### Target Encoding

# %% [markdown]
# - Performing target encoding on all categorical variables
# - Renaming the encoded columns as "ColumnName_te"
# - Dropping the original columns from the dataframe which have been encoded
# - Using the target encoded columns for the GLM model later (not GBM)

# %%
# Train a Target Encoder model
data_te = H2OTargetEncoderEstimator(#fold_column=fold_column,
                                    data_leakage_handling=None,
                                    blending=True,
                                    inflection_point=3,
                                    smoothing=10,
                                    noise=0.15,     # In general, the less data you have the more regularization you need
                                    seed=1234)

data_te.train(x=cat_columns,
              y=response,
              training_frame=loans_train,
              validation_frame=loans_valid)
# Out:
# targetencoder Model Build progress: |████████████████████████████████████████████| (done) 100%
# Model Details
# =============
# H2OTargetEncoderEstimator :  TargetEncoder
# Model Key:  TargetEncoder_model_python_1651785343446_1
#
#
# Target Encoder model summary: Summary for target encoder model
#   original_names encoded_column_names
# 0           City              City_te
# 1          State             State_te
# 2            Zip               Zip_te
# 3           Bank              Bank_te
# 4      BankState         BankState_te
# 5       NewExist          NewExist_te
# 6  FranchiseCode     FranchiseCode_te
# 7     UrbanRural        UrbanRural_te
# 8      RevLineCr         RevLineCr_te
# 9         LowDoc            LowDoc_te

# %%
# New target encoded dataset
train_te = data_te.transform(frame=loans_train, as_training=True)
test_te = data_te.transform(frame=loans_test, as_training=False)
valid_te = data_te.transform(frame=loans_valid, as_training=False)

predictors = train_te.columns
for col in cat_columns+[response]:
    predictors.remove(col)

# %%
predictors
# Out:
# ['City_te',
#  'State_te',
#  'Zip_te',
#  'Bank_te',
#  'BankState_te',
#  'NewExist_te',
#  'FranchiseCode_te',
#  'UrbanRural_te',
#  'RevLineCr_te',
#  'LowDoc_te',
#  'NAICS',
#  'NoEmp',
#  'CreateJob',
#  'RetainedJob',
#  'DisbursementGross',
#  'BalanceGross',
#  'GrAppv',
#  'SBA_Appv',
#  'LoanDisbursedPerCity',
#  'LoanPaid']

# %% [markdown]
# ## Linear Model

# %% [markdown]
# ### GLM Model

# %%
from h2o.estimators.glm import H2OGeneralizedLinearEstimator
print("Predictor columns:", predictors)    
print("Response variable:", response)

glm_model = H2OGeneralizedLinearEstimator(family="binomial",
                                          nfolds=0, #No cross-validation (faster)
                                          alpha=0,
                                          lambda_=0.3,
                                          compute_p_values=False,
                                          seed=1234,
                                          )
glm_model.train(predictors, response, training_frame= train_te, validation_frame= valid_te)
model_summary = glm_model.summary()
print(model_summary)
# Out:
# Predictor columns: ['City_te', 'State_te', 'Zip_te', 'Bank_te', 'BankState_te', 'NewExist_te', 'FranchiseCode_te', 'UrbanRural_te', 'RevLineCr_te', 'LowDoc_te', 'NAICS', 'NoEmp', 'CreateJob', 'RetainedJob', 'DisbursementGross', 'BalanceGross', 'GrAppv', 'SBA_Appv', 'LoanDisbursedPerCity', 'LoanPaid']
# Response variable: MIS_Status
# glm Model Build progress: |██████████████████████████████████████████████████████| (done) 100%
#
# GLM Model: summary
#        family   link          regularization  number_of_predictors_total  \
# 0    binomial  logit  Ridge ( lambda = 0.3 )                          20
#
#   number_of_active_predictors  number_of_iterations  \
# 0                          20                     3
#
#                       training_frame
# 0  _a0889159572b3ed6dd162bd3f2624493

# %% [markdown]
# **Testing the performance of my GLM model on the testing dataset**

# %%
glm_model.model_performance(test_te)
# Out:
# ModelMetricsBinomialGLM: glm
# ** Reported on test data. **
#
# MSE: 0.13312719757971894
# RMSE: 0.3648659994843572
# LogLoss: 0.4275442831778773
# Null degrees of freedom: 80744
# Residual degrees of freedom: 80724
# Null deviance: 74988.26800878008
# Residual deviance: 69044.12629039542
# AIC: 69086.12629039542
# AUC: 0.7202207028514012
# AUCPR: 0.38502203054333045
# Gini: 0.4404414057028023
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.20486665160911294:
#                 0        1   Error                Rate
# 0      0  51888.0  14694.0  0.2207   (14694.0/66582.0)
# 1      1   6599.0   7564.0  0.4659    (6599.0/14163.0)
# 2  Total  58487.0  22258.0  0.2637   (21293.0/80745.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
#                          metric  threshold         value    idx
# 0                        max f1   0.204867      0.415365  183.0
# 1                        max f2   0.148135      0.555255  271.0
# 2                  max f0point5   0.242762      0.406582  135.0
# 3                  max accuracy   0.320357      0.830999   68.0
# 4                 max precision   0.497299      0.941176    6.0
# 5                    max recall   0.035052      1.000000  394.0
# 6               max specificity   0.585172      0.999985    0.0
# 7              max absolute_mcc   0.229249      0.269866  150.0
# 8    max min_per_class_accuracy   0.182433      0.658829  216.0
# 9   max mean_per_class_accuracy   0.191675      0.660699  202.0
# 10                      max tns   0.585172  66581.000000    0.0
# 11                      max fns   0.585172  14163.000000    0.0
# 12                      max fps   0.007521  66582.000000  399.0
# 13                      max tps   0.035052  14163.000000  394.0
# 14                      max tnr   0.585172      0.999985    0.0
# 15                      max fnr   0.585172      1.000000    0.0
# 16                      max fpr   0.007521      1.000000  399.0
# 17                      max tpr   0.035052      1.000000  394.0
# Gains/Lift Table: Avg response rate: 17.54 %, avg score: 17.55 %
#     group  cumulative_data_fraction  lower_threshold      lift  \
# 0       1                  0.010007         0.367190  4.021832
# 1       2                  0.020001         0.337189  3.341550
# 2       3                  0.030008         0.318296  3.005790
# 3       4                  0.040002         0.304960  2.755189
# 4       5                  0.050009         0.293987  2.462490
# 5       6                  0.100006         0.259314  2.128212
# 6       7                  0.150003         0.238442  1.883898
# 7       8                  0.200000         0.223026  1.546378
# 8       9                  0.300006         0.199540  1.282135
# 9      10                  0.400000         0.181531  1.009736
# 10     11                  0.500006         0.165992  0.859934
# 11     12                  0.600000         0.151726  0.729410
# 12     13                  0.699994         0.137587  0.624200
# 13     14                  0.800000         0.122853  0.492803
# 14     15                  0.899994         0.104417  0.401776
# 15     16                  1.000000         0.002820  0.261934
#
#     cumulative_lift  response_rate     score  cumulative_response_rate  \
# 0          4.021832       0.705446  0.405468                  0.705446
# 1          3.681901       0.586121  0.350704                  0.645820
# 2          3.456438       0.527228  0.326612                  0.606273
# 3          3.281234       0.483271  0.311516                  0.575542
# 4          3.117404       0.431931  0.299242                  0.546805
# 5          2.622869       0.373297  0.274885                  0.460062
# 6          2.376566       0.330443  0.248177                  0.416859
# 7          2.169032       0.271241  0.230429                  0.380457
# 8          1.873387       0.224892  0.210619                  0.328600
# 9          1.657488       0.177112  0.190154                  0.290730
# 10         1.497969       0.150836  0.173666                  0.262750
# 11         1.369884       0.127942  0.158855                  0.240283
# 12         1.263363       0.109487  0.144637                  0.221599
# 13         1.167037       0.086440  0.130395                  0.204703
# 14         1.082013       0.070473  0.114068                  0.189789
# 15         1.000000       0.045944  0.086159                  0.175404
#
#     cumulative_score  capture_rate  cumulative_capture_rate        gain  \
# 0           0.405468      0.040246                 0.040246  302.183157
# 1           0.378103      0.033397                 0.073643  234.155020
# 2           0.360932      0.030078                 0.103721  200.578991
# 3           0.348586      0.027537                 0.131258  175.518938
# 4           0.338712      0.024642                 0.155899  146.248985
# 5           0.306803      0.106404                 0.262303  112.821199
# 6           0.287262      0.094189                 0.356492   88.389834
# 7           0.273055      0.077314                 0.433806   54.637832
# 8           0.252242      0.128221                 0.562028   28.213483
# 9           0.236721      0.100967                 0.662995    0.973562
# 10          0.224109      0.085999                 0.748994  -14.006596
# 11          0.213234      0.072937                 0.821930  -27.058958
# 12          0.203435      0.062416                 0.884347  -37.579980
# 13          0.194304      0.049283                 0.933630  -50.719708
# 14          0.185390      0.040175                 0.973805  -59.822408
# 15          0.175466      0.026195                 1.000000  -73.806607
#
#     cumulative_gain  kolmogorov_smirnov
# 0        302.183157            0.036671
# 1        268.190150            0.065052
# 2        245.643795            0.089393
# 3        228.123436            0.110666
# 4        211.740436            0.128414
# 5        162.286943            0.196820
# 6        137.656607            0.250413
# 7        116.903198            0.283541
# 8         87.338739            0.317758
# 9         65.748782            0.318938
# 10        49.796916            0.301951
# 11        36.988397            0.269138
# 12        26.336337            0.223567
# 13        16.703735            0.162055
# 14         8.201298            0.089512
# 15         0.000000            0.000000

# %% [markdown]
# ## Boosted Tree Model

# %% [markdown]
# ### GBM

# %%
from h2o.estimators import H2OGradientBoostingEstimator

# %%
predictors_gbm = loans_train.columns
predictors_gbm.remove(response)

# %%
gbm_model = H2OGradientBoostingEstimator(nfolds=0,
                                         seed=1234,
                                         ntrees=500,
                                         stopping_rounds=5,
                                         stopping_metric = 'AUC',
                                         keep_cross_validation_predictions = False)

# %%
gbm_model.train(x=predictors_gbm, 
                y=response, 
                training_frame=loans_train, 
                validation_frame = loans_valid)
# Out:
# gbm Model Build progress: |██████████████████████████████████████████████████████| (done) 100%
# Model Details
# =============
# H2OGradientBoostingEstimator :  Gradient Boosting Machine
# Model Key:  GBM_model_python_1651785343446_6
#
#
# Model Summary:
#      number_of_trees  number_of_internal_trees  model_size_in_bytes  \
# 0              140.0                     140.0              96126.0
#
#    min_depth  max_depth  mean_depth  min_leaves  max_leaves  mean_leaves
# 0        0.0        5.0    4.964286         1.0        32.0    30.671429
# ModelMetricsBinomial: gbm
# ** Reported on train data. **
#
# MSE: 0.11075921168047778
# RMSE: 0.3328050655871659
# LogLoss: 0.3605889941654156
# Mean Per-Class Error: 0.27669439828041836
# AUC: 0.8158417181035447
# AUCPR: 0.5377415254568007
# Gini: 0.6316834362070893
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.24743978309817832:
#                  0         1   Error                  Rate
# 0      0  456781.0   75873.0  0.1424    (75873.0/532654.0)
# 1      1   46563.0   66744.0  0.4109    (46563.0/113307.0)
# 2  Total  503344.0  142617.0  0.1895   (122436.0/645961.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
#                          metric  thresh
# 8           0.380911      0.122644                 0.666243   22.635914
# 9           0.327334      0.093130                 0.759373   -6.864246
# 10          0.287471      0.071948                 0.831321  -28.056421
# 11          0.256193      0.058533                 0.889854  -41.463579
# 12          0.230716      0.044906                 0.934760  -55.091479
# 13          0.209497      0.032903                 0.967662  -67.099404
# 14          0.191454      0.022806                 0.990468  -77.192685
# 15          0.175155      0.009532                 1.000000  -90.468711
#
#     cumulative_gain  kolmogorov_smirnov
# 0        384.736542            0.046689
# 1        358.560886            0.086972
# 2        347.054603            0.126297
# 3        328.907988            0.159559
# 4        312.124245            0.189294
# 5        248.562755            0.301454
# 6        205.390387            0.373628
# 7        171.799760            0.416688
# 8        122.076425            0.444141
# 9         89.843254            0.435817
# 10        66.262150            0.401791
# 11        48.308974            0.351510
# 12        33.538265            0.284704
# 13        20.957777            0.203327
# 14        10.052771            0.109720
# 15         0.000000            0.000000

# %% [markdown]
# ## Model Tuning
#
# - Performing model tuning for my GBM model here
# - Not performing the cross validation here (nfolds=0) and instead using the validation_frame parameter
# - Because it is a regression model, I am using the stopping metric as AUC
# - In my grid search, I am tuning the following parameters using Cartesian search criteria - ntrees, learn_rate, max_depth, sample_rate, col_sample_rate, `balance_classes` and max_after_balance_size
# - Since the dataset is heavily imbalanced, I am using balance_classes parameter to balance the classes.

# %%
from h2o.grid.grid_search import H2OGridSearch

gbm_model_tunes = H2OGradientBoostingEstimator(nfolds=0,
                                              seed = 1234, 
                                              stopping_metric= 'AUC',
                                              stopping_rounds=5,
                                              keep_cross_validation_predictions = False)

gbm_params1_loans = { 
                'ntrees':[250,500],
                'learn_rate': [0.01, 0.1],
                'max_depth': [3, 5, 9],
                'sample_rate': [0.8],
                'col_sample_rate': [1.0],
                'balance_classes': [True, False],
                'max_after_balance_size': [0.85, 1.7]
              }

#Train and validate a cartesian grid of GBMs
gbm_grid1_loans = H2OGridSearch(model=gbm_model_tunes,
                          grid_id='gbm_grid1',
                          hyper_params=gbm_params1_loans,
                          search_criteria = {'strategy': "Cartesian"})

gbm_grid1_loans.train(x=predictors_gbm, y=response,
                training_frame=loans_train,
                validation_frame = loans_valid)
# Out:
# gbm Grid Build progress: |███████████████████████████████████████████████████████| (done) 100%
#       balance_classes  col_sample_rate  learn_rate  max_after_balance_size  \
# 0                true              1.0        0.10                    1.70
# 1                true              1.0        0.10                    1.70
# 2               false              1.0        0.10                    0.85
# 3               false              1.0        0.10                    1.70
# 4               false              1.0        0.10                    0.50
# .. ..             ...              ...         ...                     ...
# 91               true              1.0        0.01                    0.85
# 92               true              1.0        0.01                    0.85
# 93               true              1.0        0.01                    0.85
# 94               true              1.0        0.01                    0.50
# 95               true              1.0        0.01                    0.50
#
#     max_depth  ntrees  sample_rate            model_ids   logloss
# 0         9.0   500.0          0.8  gbm_grid1_model_120  0.350617
# 1         9.0   250.0          0.8   gbm_grid1_model_96  0.350617
# 2         9.0   500.0          0.8  gbm_grid1_model_117  0.352419
# 3         9.0   500.0          0.8  gbm_grid1_model_121  0.352419
# 4         9.0   250.0          0.8   gbm_grid1_model_82  0.352419
# ..        ...     ...          ...                  ...       ...
# 91        3.0    50.0          0.8    gbm_grid1_model_1  0.455303
# 92        3.0   500.0          0.8   gbm_grid1_model_13  0.455303
# 93        3.0   250.0          0.8    gbm_grid1_model_7  0.455303
# 94        3.0    50.0          0.8   gbm_grid1_model_19  0.456051
# 95        3.0   250.0          0.8   gbm_grid1_model_55  0.456051
#
# [96 rows x 10 columns]

# %% [markdown]
# **Sorting the results of my grid search in descending order based on AUC to get the model with highest AUC**

# %%
gbm_gridperf1 = gbm_grid1_loans.get_grid(sort_by='AUC', decreasing=True)
gbm_gridperf1
# Out:
#       balance_classes  col_sample_rate  learn_rate  max_after_balance_size  \
# 0                true              1.0        0.10                    1.70
# 1                true              1.0        0.10                    1.70
# 2                true              1.0        0.10                    0.85
# 3                true              1.0        0.10                    0.85
# 4               false              1.0        0.10                    0.85
# .. ..             ...              ...         ...                     ...
# 91               true              1.0        0.01                    0.50
# 92               true              1.0        0.01                    0.50
# 93               true              1.0        0.01                    0.85
# 94               true              1.0        0.01                    0.85
# 95               true              1.0        0.01                    0.85
#
#     max_depth  ntrees  sample_rate            model_ids       auc
# 0         9.0   500.0          0.8  gbm_grid1_model_120  0.831238
# 1         9.0   250.0          0.8   gbm_grid1_model_96  0.831238
# 2         9.0   250.0          0.8   gbm_grid1_model_12  0.828202
# 3         9.0   500.0          0.8   gbm_grid1_model_18  0.828202
# 4         9.0   500.0          0.8  gbm_grid1_model_117  0.827512
# ..        ...     ...          ...                  ...       ...
# 91        3.0    50.0          0.8   gbm_grid1_model_19  0.723360
# 92        3.0   250.0          0.8   gbm_grid1_model_55  0.723360
# 93        3.0    50.0          0.8    gbm_grid1_model_1  0.723248
# 94        3.0   500.0          0.8   gbm_grid1_model_13  0.723248
# 95        3.0   250.0          0.8    gbm_grid1_model_7  0.723248
#
# [96 rows x 10 columns]

# %%
bestmodel_gbm = gbm_gridperf1.models[0]
bestmodel_gbm
# Out:
# Model Details
# =============
# H2OGradientBoostingEstimator :  Gradient Boosting Machine
# Model Key:  gbm_grid1_model_120
#
#
# Model Summary:
#      number_of_trees  number_of_internal_trees  model_size_in_bytes  \
# 0              379.0                     379.0             824864.0
#
#    min_depth  max_depth  mean_depth  min_leaves  max_leaves  mean_leaves
# 0        0.0        9.0     2.44591         1.0       492.0   101.261215
# ModelMetricsBinomial: gbm
# ** Reported on train data. **
#
# MSE: 0.22831494668410135
# RMSE: 0.4778231332659621
# LogLoss: 0.6499941341830763
# Mean Per-Class Error: 0.2055009634350915
# AUC: 0.878277744310636
# AUCPR: 0.8650119434949676
# Gini: 0.756555488621272
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.13283757592084058:
#                  0         1   Error                   Rate
# 0      0  379375.0  153279.0  0.2878    (153279.0/532654.0)
# 1      1   65639.0  466984.0  0.1232     (65639.0/532623.0)
# 2  Total  445014.0  620263.0  0.2055   (218918.0/1065277.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
#                          metric  threshold          value    idx
# 0                        max f1   0.132838       0.810113  306.0
# 1                        max f2   0.066834       0.881717  349.0
# 2                  max f0point5   0.219659       0.802898  259.0
# 3                  max accuracy   0.153922       0.798692  294.0
# 4                 max precision   0.931304       1.000000    0.0
# 5                    max recall   0.012396       1.000000  392.0
# 6               max specificity   0.931304       1.000000    0.0
# 7              max absolute_mcc   0.143316       0.600106  300.0
# 8    max min_per_class_accuracy   0.177133       0.795635  281.0
# 9   max mean_per_class_accuracy   0.153922       0.798693  294.0
# See the whole table with table.as_data_frame()
#
# Variable Importances:
#                 variable  relative_importance  scaled_importance  percentage
# 0             UrbanRural        126265.539062           1.000000    0.249799
# 1              BankState         89183.617188           0.706318    0.176437
# 2                  State         60163.890625           0.476487    0.119026
# 3                   Bank         56285.390625           0.445770    0.111353
# 4               SBA_Appv         54717.816406           0.433355    0.108252
# 5              RevLineCr         22104.984375           0.175067    0.043732
# 6                  NAICS         20756.207031           0.164385    0.041063
# 7          FranchiseCode         17810.583984           0.141057    0.035236
# 8                    Zip          9296.189453           0.073624    0.018391
# 9                 GrAppv          8673.561523           0.068693    0.017159
# 10              NewExist          8306.360352           0.065785    0.016433
# 11                  City          7807.085449           0.061831    0.015445
# 12     DisbursementGross          7600.009277           0.060191    0.015036
# 13                LowDoc          4129.461914           0.032705    0.008170
# 14                 NoEmp          3669.812012           0.029064    0.007260
# 15             CreateJob          2881.578857           0.022822    0.005701
# 16  LoanDisbursedPerCity          2229.713379           0.017659    0.004411
# 17              LoanPaid          2196.811035           0.017398    0.004346
# 18           RetainedJob          1390.263428           0.011011    0.002750
# 19          BalanceGross             0.000000           0.000000    0.000000

# %% [markdown]
# **The parameters selected by the grid search for the best model are:**

# %%
print("The best set of parameters for the GBM function:")
print("Best value for ntrees", bestmodel_gbm.actual_params['ntrees'])
print("Best value for learn rate", bestmodel_gbm.actual_params['learn_rate'])
print("Best value for max_depth", bestmodel_gbm.actual_params['max_depth'])
print("Best value for sample_rate", bestmodel_gbm.actual_params['sample_rate'])
print("Best value for col_sample_rate", bestmodel_gbm.actual_params['col_sample_rate'])
print("Best value for balance_classes", bestmodel_gbm.actual_params['balance_classes'])
print("Best value for max_after_balance_size", bestmodel_gbm.actual_params['max_after_balance_size'])
# Out:
# The best set of parameters for the GBM function:
# Best value for ntrees 500
# Best value for learn rate 0.1
# Best value for max_depth 9
# Best value for sample_rate 0.8
# Best value for col_sample_rate 1.0
# Best value for balance_classes True
# Best value for max_after_balance_size 1.7

# %% [markdown]
# ### Saving my best model

# %%
# save the model
model_path = h2o.save_model(model=bestmodel_gbm, path="/Users/General/Documents/UTD/Semester 3/Applied Machine Learning/Projects/Project 2/SBALoans/artifacts_SBALoans", force=True)
print(model_path)
# Out:
# C:\Users\General\Documents\UTD\Semester 3\Applied Machine Learning\Projects\Project 2\SBALoans\artifacts_SBALoans\gbm_grid1_model_120

# %%
# upload the model that you just downloded above
# to the H2O cluster
model_path = "./artifacts_SBALoans/gbm_grid1_model_120"

# %%
best_gbm_sba = h2o.upload_model(model_path)

# %% [markdown]
# **A function to evaluate the performance of the model**

# %%
def evaluate_model(eval_loans_model):
    print("AUC:", eval_loans_model.auc())
    print("Accuracy:", eval_loans_model.accuracy()[0][1])
    print("AUCPR:", eval_loans_model.aucpr())
    print("F0point5:",  eval_loans_model.F0point5()[0][1])
    print("F1:",  eval_loans_model.F1()[0][1])
    print("F2:", eval_loans_model.F2()[0][1])
    print("Precision:", eval_loans_model.precision()[0][1])
    print("Recall:", eval_loans_model.recall()[0][1])

# %%
eval_loans_train = best_gbm_sba.model_performance(loans_train)
eval_loans_test = best_gbm_sba.model_performance(loans_test)

# %% [markdown]
# **Final metrics of the best tuned GBM model using training dataset**

# %%
print("Model Performance on Training dataset:")
evaluate_model(eval_loans_train)
# Out:
# Model Performance on Training dataset:
# AUC: 0.8780567711992329
# Accuracy: 0.86065257809682
# AUCPR: 0.6148390646593466
# F0point5: 0.5948091645285993
#
#     cumulative_score  capture_rate  cumulative_capture_rate        gain  \
# 0           0.799380      0.049072                 0.049072  390.381217
# 1           0.766414      0.045541                 0.094613  355.665936
# 2           0.737093      0.041234                 0.135847  312.061340
# 3           0.708464      0.036574                 0.172421  265.945667
# 4           0.682388      0.034809                 0.207230  247.853151
# 5           0.588166      0.150533                 0.357763  201.084802
# 6           0.518673      0.116995                 0.474758  134.004464
# 7           0.464225      0.092918                 0.567676   85.847842
# 8           0.383340      0.135000                 0.702676   34.991288
# 9           0.325619      0.097437                 0.800113   -2.556982
# 10          0.282192      0.066017                 0.866130  -33.987001
# 11          0.248119      0.049072                 0.915202  -50.925437
# 12          0.220621      0.037492                 0.952694  -62.505621
# 13          0.198020      0.027325                 0.980018  -72.676973
# 14          0.178983      0.015533                 0.995552  -84.465606
# 15          0.162214      0.004448                 1.000000  -95.552065
#
#     cumulative_gain  kolmogorov_smirnov
# 0        390.381217            0.047374
# 1        373.034325            0.090482
# 2        352.701608            0.128352
# 3        331.026052            0.160586
# 4        314.383233            0.190664
# 5        257.741033            0.312586
# 6        216.498916            0.393835
# 7        183.838170            0.445887
# 8        134.220494            0.488324
# 9        100.028243            0.485223
# 10        73.223866            0.444004
# 11        52.533597            0.382250
# 12        36.100295            0.306453
# 13        22.502295            0.218311
# 14        10.617627            0.115885
# 15         0.000000            0.000000

# %% [markdown]
# ## Interpreting Final Trained Model

# %%
import shap

# %% [markdown]
# **Global feature importance using Shapley values**

# %%
best_gbm_sba.varimp_plot()

# %% [markdown]
# Using Global level interpretation of model using shapley values:
# - The most important feature is `UrbanRural`
# - It is followed by `BankState` and `State` and so on

# %% [markdown]
# **Calculating and Plotting permutation feature importance**

# %%
# calculate importance
permutation_varimp = best_gbm_sba.permutation_importance(loans_test, use_pandas=True)

# plot permutation importance (bar plot)
best_gbm_sba.permutation_importance_plot(loans_test)
# Out:
# Variable Importances:
#                 Variable  Relative Importance  Scaled Importance  Percentage
# 0              BankState             0.109051           1.000000    0.220818
# 1               SBA_Appv             0.095316           0.874050    0.193006
# 2             UrbanRural             0.078504           0.719890    0.158965
# 3                   Bank             0.050464           0.462759    0.102186
# 4                  State             0.034704           0.318240    0.070273
# 5                 GrAppv             0.027559           0.252716    0.055804
# 6                  NAICS             0.023225           0.212976    0.047029
# 7              RevLineCr             0.018818           0.172560    0.038104
# 8          FranchiseCode             0.016943           0.155372    0.034309
# 9      DisbursementGross             0.015571           0.142783    0.031529
# 10              LoanPaid             0.009031           0.082816    0.018287
# 11                 NoEmp             0.003910           0.035852    0.007917
# 12             CreateJob             0.003207           0.029404    0.006493
# 13                LowDoc             0.002550           0.023379    0.005163
# 14              NewExist             0.001787           0.016391    0.003619
# 15  LoanDisbursedPerCity             0.001390           0.012744    0.002814
# 16                   Zip             0.000896           0.008219    0.001815
# 17                  City             0.000703           0.006449    0.001424
# 18           RetainedJob             0.000219           0.002009    0.000444
# 19          BalanceGross             0.000000           0.000000    0.000000

# %% [markdown]
# Using feature permutation importance:
# - The most important feature is `BankState`
# - That is followed by `SBA_Appv` and `UrbanRural` and so on

# %% [markdown]
# **Summary plot with Shapley values**

# %%
def examine_all_reason_codes(data, model):
    
    shap_contribs = model.predict_contributions(data)
    
    col_mapping = {}
    for i in data.col_names: 
        related_cols = [x for x in shap_contribs.col_names if "{}.".format(i) in x]
        if len(related_cols) > 0:
            col_mapping[i] = related_cols
            
    for k, v in col_mapping.items():
        if len(v) > 1:
            shap_contribs[k] = shap_contribs[v].sum(axis=1,return_frame=True)
            shap_contribs = shap_contribs.drop(v)
        
    shap_cols = [i for i in shap_contribs.col_names if i != "BiasTerm"]
    bias_term = shap_contribs.as_data_frame()["BiasTerm"].values
    X = data.as_data_frame(use_pandas=True)
    shap_contribs = shap_contribs.as_data_frame(use_pandas=True)
    
    return shap.summary_plot(shap_contribs[shap_cols].values, 
                             X[shap_cols].values,
                             feature_names=shap_cols
                            )

# %%
examine_all_reason_codes(loans_test, best_gbm_sba)
# Out:
# contributions progress: |████████████████████████████████████████████████████████| (done) 100%

# %% [markdown]
# The above summary plot shows that:
# - The most important feature is `UrbanRural`. It looks like it has a positive correlation with SHAP values. The higher the value of `UrbanRural` feature, the higher is the SHAP value(impact on model output)
# - The second important deature is `SBA_Appv`. It has a negative correlation with SHAP values. The higher the value of `SBA_Appv`, the lower is the SHAP value(impact on model output)

# %% [markdown]
# ## Individual observations analysis using Shapley values

# %%
preds1 = best_gbm_sba.predict(loans_test)
preds1
# Out:
# gbm prediction progress: |███████████████████████████████████████████████████████| (done) 100%
# <table>
# <thead>
# <tr><th style="text-align: right;">  predict</th><th style="text-align: right;">      p0</th><th style="text-align: right;">       p1</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">        0</td><td style="text-align: right;">0.975773</td><td style="text-align: right;">0.0242274</td></tr>
# <tr><td style="text-align: right;">        0</td><td style="text-align: right;">0.897286</td><td style="text-align: right;">0.102714 </td></tr>
# <tr><td style="text-align: right;">        1</td><td style="text-align: right;">0.231145</td><td style="text-align: right;">0.768855 </td></tr>
# <tr><td style="text-align: right;">        0</td><td style="text-align: right;">0.826035</td><td style="text-align: right;">0.173965 </td></tr>
# <tr><td style="text-align: right;">        0</td><td style="text-align: right;">0.859061</td><td style="text-align: right;">0.140939 </td></tr>
# <tr><td style="text-align: right;">        1</td><td style="text-align: right;">0.622533</td><td style="text-align: right;">0.377467 </td></tr>
# <tr><td style="text-align: right;">        0</td><td style="text-align: right;">0.964618</td><td style="text-align: right;">0.0353818</td></tr>
# <tr><td style="text-align: right;">        0</td><td style="text-align: right;">0.912058</td><td style="text-align: right;">0.087942 </td></tr>
# <tr><td style="text-align: right;">        0</td><td style="text-align: right;">0.888555</td><td style="text-align: right;">0.111445 </td></tr>
# <tr><td style="text-align: right;">        1</td><td style="text-align: right;">0.742951</td><td style="text-align: right;">0.257049 </td></tr>
# </tbody>
# </table>

# %%
yhat = 'p_MIS_Status'
resid = 'r_MIS_Status'
preds1 = best_gbm_sba.predict(loans_test).drop(['predict', 'p0'])
preds1.columns = [yhat]
test_yhat = loans_test.cbind(preds1[yhat])
# Out:
# gbm prediction progress: |███████████████████████████████████████████████████████| (done) 100%

# %%
test_yhat.head(3)
# Out:
# <table>
# <thead>
# <tr><th>City       </th><th>State  </th><th style="text-align: right;">  Zip</th><th>Bank                          </th><th>BankState  </th><th style="text-align: right;">  NAICS</th><th style="text-align: right;">  NoEmp</th><th style="text-align: right;">  NewExist</th><th style="text-align: right;">  CreateJob</th><th style="text-align: right;">  RetainedJob</th><th style="text-align: right;">  FranchiseCode</th><th style="text-align: right;">  UrbanRural</th><th>RevLineCr  </th><th>LowDoc  </th><th style="text-align: right;">  DisbursementGross</th><th style="text-align: right;">  BalanceGross</th><th style="text-align: right;">  GrAppv</th><th style="text-align: right;">  SBA_Appv</th><th style="text-align: right;">  MIS_Status</th><th style="text-align: right;">  LoanDisbursedPerCity</th><th style="text-align: right;">  LoanPaid</th><th style="text-align: right;">  p_MIS_Status</th></tr>
# </thead>
# <tbody>
# <tr><td>RIPON      </td><td>WI     </td><td style="text-align: right;">54971</td><td>U.S. BANK NATIONAL ASSOCIATION</td><td>WI         </td><td style="text-align: right;"> 722410</td><td style="text-align: right;">      3</td><td style="text-align: right;">         1</td><td style="text-align: right;">          0</td><td style="text-align: right;">            0</td><td style="text-align: right;">              1</td><td style="text-align: right;">           0</td><td>N          </td><td>N       </td><td style="text-align: right;">             210000</td><td style="text-align: right;">             0</td><td style="text-align: right;">  210000</td><td style="text-align: right;">    157500</td><td style="text-align: right;">           0</td><td style="text-align: right;">           1.36082e+07</td><td style="text-align: right;">    210000</td><td style="text-align: right;">     0.0242274</td></tr>
# <tr><td>ORANGE PARK</td><td>FL     </td><td style="text-align: right;">32065</td><td>BRANCH BK. &amp; TR CO            </td><td>NC         </td><td style="text-align: right;"> 621210</td><td style="text-align: right;">      3</td><td style="text-align: right;">         2</td><td style="text-align: right;">          0</td><td style="text-align: right;">            3</td><td style="text-align: right;">              0</td><td style="text-align: right;">           1</td><td>N          </td><td>Missing </td><td style="text-align: right;">             391500</td><td style="text-align: right;">             0</td><td style="text-align: right;">  391500</td><td style="text-align: right;">    352350</td><td style="text-align: right;">           0</td><td style="text-align: right;">           3.49567e+07</td><td style="text-align: right;">    391500</td><td style="text-align: right;">     0.102714 </td></tr>
# <tr><td>NORTH PORT </td><td>FL     </td><td style="text-align: right;">34286</td><td>SUPERIOR FINANCIAL GROUP, LLC </td><td>CA         </td><td style="text-align: right;"> 561710</td><td style="text-align: right;">      2</td><td style="text-align: right;">         1</td><td style="text-align: right;">          1</td><td style="text-align: right;">            2</td><td style="text-align: right;">              0</td><td style="text-align: right;">           1</td><td>N          </td><td>N       </td><td style="text-align: right;">              12500</td><td style="text-align: right;">             0</td><td style="text-align: right;">   12500</td><td style="text-align: right;">     11250</td><td style="text-align: right;">           0</td><td style="text-align: right;">           5.46334e+06</td><td style="text-align: right;">     12500</td><td style="text-align: right;">     0.768855 </td></tr>
# </tbody>
# </table>

# %% [markdown]
# **Adding Shapley values (contributions)**

# %%
pred_contributions_orig_table = best_gbm_sba.predict_contributions(loans_test)
# Out:
# contributions progress: |████████████████████████████████████████████████████████| (done) 100%

# %%
contrib_columns = []
for col in loans_test.columns:
    if col not in ['BiasTerm','MIS_Status']:
        contrib_columns.append("contrib_"+col)

contrib_columns.append('BiasTerm')
pred_contributions_orig_table.columns = contrib_columns

test_yhat = test_yhat.cbind(pred_contributions_orig_table)

include_columns = loans_test.columns

# %%
test_yhat.head(2)
# Out:
# <table>
# <thead>
# <tr><th>City       </th><th>State  </th><th style="text-align: right;">  Zip</th><th>Bank                          </th><th>BankState  </th><th style="text-align: right;">  NAICS</th><th style="text-align: right;">  NoEmp</th><th style="text-align: right;">  NewExist</th><th style="text-align: right;">  CreateJob</th><th style="text-align: right;">  RetainedJob</th><th style="text-align: right;">  FranchiseCode</th><th style="text-align: right;">  UrbanRural</th><th>RevLineC
# <tr><td>ORANGE PARK</td><td>FL     </td><td style="text-align: right;">32065</td><td>BRANCH BK. &amp; TR CO            </td><td>NC         </td><td style="text-align: right;"> 621210</td><td style="text-align: right;">      3</td><td style="text-align: right;">         2</td><td style="text-align: right;">          0</td><td style="text-align: right;">            3</td><td style="text-align: right;">              0</td><td style="text-align: right;">           1</td><td>N          </td><td>Missing </td><td style="text-align: right;">             391500</td><td style="text-align: right;">             0</td><td style="text-align: right;">  391500</td><td style="text-align: right;">    352350</td><td style="text-align: right;">           0</td><td style="text-align: right;">           3.49567e+07</td><td style="text-align: right;">    391500</td><td style="text-align: right;">     0.102714 </td><td style="text-align: right;">    -0.0121643</td><td style="text-align: right;">      0.278417 </td><td style="text-align: right;">  -0.0270524 </td><td style="text-align: right;">     -0.130292</td><td style="text-align: right;">          -0.014363</td><td style="text-align: right;">      -0.928424</td><td style="text-align: right;">      0.0231287</td><td style="text-align: right;">         0.140178 </td><td style="text-align: right;">          0.0223589</td><td style="text-align: right;">          -0.0138619 </td><td style="text-align: right;">              0.119724 </td><td style="text-align: right;">            0.197474</td><td style="text-align: right;">          0.101617 </td><td style="text-align: right;">        0.268259</td><td style="text-align: right;">                0.0149943  </td><td style="text-align: right;">                     0</td><td style="text-align: right;">       0.0793963</td><td style="text-align: right;">         -0.851573</td><td style="text-align: right;">                    0.00620921</td><td style="text-align: right;">         0.120824 </td><td style="text-align: right;">-0.0145612</td></tr>
# </tbody>
# </table>

# %% [markdown]
# Calculate deviance residuals for binomial classification
# For binomial classification, deviance residuals are related to the logloss cost function. Like analyzing `y−ŷ`
#  for linear regression, these residuals are the quantities that the GBM sought to minimize. Deviance residual values are calculated by applying the simple formula in the cell directly below.

# %%
# use Pandas for adding columns and plotting
test_yhat = test_yhat.as_data_frame()
test_yhat['s'] = 1
test_yhat.loc[test_yhat['MIS_Status'] == 0, 's'] = -1

# %%
y = 'MIS_Status'
test_yhat['r_MIS_Status'] = test_yhat['s'] * np.sqrt(-2*(test_yhat[y]*np.log(test_yhat[yhat]) +
                                                                 ((1 - test_yhat[y])*np.log(1 - test_yhat[yhat]))))
test_yhat = test_yhat.drop('s', axis=1)

# %%
test_yhat.head(2)
# Out:
#           City State    Zip                            Bank BankState   NAICS  \
# 0        RIPON    WI  54971  U.S. BANK NATIONAL ASSOCIATION        WI  722410
# 1  ORANGE PARK    FL  32065              BRANCH BK. & TR CO        NC  621210
#
#    NoEmp  NewExist  CreateJob  RetainedJob  FranchiseCode  UrbanRural  \
# 0      3         1          0            0              1           0
# 1      3         2          0            3              0           1
#
#   RevLineCr   LowDoc  DisbursementGross  BalanceGross  GrAppv  SBA_Appv  \
# 0         N        N             210000             0  210000    157500
# 1         N  Missing             391500             0  391500    352350
#
#    MIS_Status  LoanDisbursedPerCity  LoanPaid  p_MIS_Status  contrib_City  \
# 0           0              13608154    210000      0.024227     -0.029395
# 1           0              34956664    391500      0.102714     -0.012164
#
#    contrib_State  contrib_Zip  contrib_Bank  contrib_BankState  contrib_NAICS  \
# 0      -0.012922    -0.006306     -0.123060          -0.427321      -0.189259
# 1       0.278417    -0.027052     -0.130292          -0.014363      -0.928424
#
#    contrib_NoEmp  contrib_NewExist  contrib_CreateJob  contrib_RetainedJob  \
# 0       0.011343         -0.067862           0.031610            -0.005632
# 1       0.023129          0.140178           0.022359            -0.013862
#
#    contrib_FranchiseCode  contrib_UrbanRural  contrib_RevLineCr  \
# 0              -0.085354           -1.036738          -0.049196
# 1               0.119724            0.197474           0.101617
#
#    contrib_LowDoc  contrib_DisbursementGross  contrib_BalanceGross  \
# 0        0.015152                   0.000796                     0
# 1        0.268259                   0.014994                     0
#
#    contrib_GrAppv  contrib_SBA_Appv  contrib_LoanDisbursedPerCity  \
# 0       -0.154629         -0.112514                      0.027830
# 1        0.079396         -0.851573                      0.006209
#
#    contrib_LoanPaid  BiasTerm  r_MIS_Status
# 0          0.079985 -0.014561     -0.221476
# 1          0.120824 -0.014561     -0.465577

# %%
test_yhat = test_yhat.sort_values(by='r_MIS_Status', ascending=False).reset_index(drop=True)
test_yhat.head(5)
# Out:
#              City State    Zip                            Bank BankState  \
# 0        BILLINGS    MT  59102  WESTERN SECURITY BANK A DIVISI        MT
# 1   BEVERLY HILLS    CA  90211             1ST CENTENNIAL BANK        CA
# 2  NORTH TAZEWELL    VA  24630              BRANCH BK. & TR CO        VA
# 3          VIENNA    VA  22180            WASHINGTONFIRST BANK        VA
# 4          COUNCE    TN  38326               BANCORPSOUTH BANK        MS
#
#     NAICS  NoEmp  NewExist  CreateJob  RetainedJob  FranchiseCode  UrbanRural  \
# 0  621310      5         1          0            5              1           1
# 1       0      1         2          0            0              1           1
# 2       0     64         1          0            0              1           0
# 3  541511     28         1          0            0              1           0
# 4  212321     26         1          0            0              1           0
#
#   RevLineCr LowDoc  DisbursementGross  BalanceGross  GrAppv  SBA_Appv  \
# 0         Y      N             151945             0   40000     20000
# 1         N      N              35000             0   35000     28000
# 2         N      N             700000             0  700000    595000
# 3         Y      N             457564             0  400000    300000
# 4         N      N              93502             0  266660    199995
#
#    MIS_Status  LoanDisbursedPerCity  LoanPaid  p_MIS_Status  contrib_City  \
# 0           1             203372653    151945      0.004712     -0.020374
# 1           1              54067149     35000      0.007712     -0.043300
# 2           1                700000    700000      0.008755      0.006621
# 3           1              58426236    457564      0.009090     -0.038167
# 4           1               3414902     93502      0.009668     -0.012995
#
#    contrib_State  contrib_Zip  contrib_Bank  contrib_BankState  contrib_NAICS  \
# 0      -0.739418    -0.001571     -0.786001          -1.023354      -0.476850
# 1      -0.118263    -0.097664     -1.465484          -0.457594      -0.746011
# 2      -0.454181    -0.025519     -0.141854          -0.347369      -0.087212
# 3      -0.370360    -0.007984     -0.653125          -0.175808      -0.387390
# 4      -0.047502    -0.015899     -0.324065          -0.703679      -0.273487
#
#    contrib_NoEmp  contrib_NewExist  contrib_CreateJob  contrib_RetainedJob  \
# 0      -0.039283         -0.023369          -0.016351            -0.000895
# 1      -0.047417          0.047956           0.007440            -0.000734
# 2      -0.556405         -0.088851           0.089413             0.001298
# 3      -0.246215         -0.075675           0.006173            -0.019980
# 4      -0.226362         -0.068707           0.070742            -0.000494
#
#    contrib_FranchiseCode  contrib_UrbanRural  contrib_RevLineCr  \
# 0              -0.033995            0.104894          -0.109433
# 1              -0.092881            0.075790          -0.262389
# 2              -0.174003           -0.596359          -0.037547
# 3              -0.099106           -0.413711          -0.116302
# 4              -0.116280           -0.453192          -0.074679
#
#    contrib_LowDoc  contrib_DisbursementGross  contrib_BalanceGross  \
# 0       -0.000510                  -0.242061                     0
# 1        0.005288                  -0.032064                     0
# 2       -0.001231                   0.008734                     0
# 3        0.000773                  -0.010263                     0
# 4        0.018441                  -0.091373                     0
#
#    contrib_GrAppv  contrib_SBA_Appv  contrib_LoanDisbursedPerCity  \
# 0       -0.275249          0.054953                     -0.013839
# 1       -0.018973          0.021860                     -0.005642
# 2        0.121542         -0.940277                      0.021118
# 3       -0.065991         -0.514404                     -0.006990
# 4       -0.082791         -0.479634                     -0.086245
#
#    contrib_LoanPaid  BiasTerm  r_MIS_Status
# 0         -0.147841 -0.014561      3.273391
# 1         -0.064883 -0.014561      3.119289
# 2          0.035009 -0.014561      3.078358
# 3          0.065327 -0.014561      3.066139
# 4         -0.098779 -0.014561      3.045971

# %%
shap.initjs()
def examine_indiv_reason_codes(df_vals_and_cotribs,
                               rec_num, 
                               include_columns, 
                               contrib_columns,
                               use_matplotlib=False):
    
    shap_columns = contrib_columns.copy()
    shap_columns.remove("BiasTerm")
    ftr_columns = include_columns.copy()
    ftr_columns.remove("MIS_Status")
    bias = df_vals_and_cotribs['BiasTerm'].iloc[rec_num]
    shap_contribs = df_vals_and_cotribs[shap_columns].iloc[rec_num,:].values
    ftr_values =    df_vals_and_cotribs[ftr_columns].iloc[rec_num,:].values
    
    return shap.force_plot(bias, 
                           shap_contribs, 
                           ftr_values, 
                           shap_columns,
                           link="logit",
                           matplotlib=use_matplotlib)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
correct_test_yhat = test_yhat
correct_test_yhat['r_MIS_Status_abs'] = abs(correct_test_yhat['r_MIS_Status'])

# %%
correct_test_yhat = correct_test_yhat.sort_values(by='r_MIS_Status_abs', ascending=False).reset_index(drop=True)

# %% [markdown]
# ### 1. Label 0 is correctly identified

# %%
correct_test_yhat[correct_test_yhat['MIS_Status'] == 0].tail(2)
# Out:
#                 City State   Zip                         Bank BankState  \
# 80743  WEST CALDWELL    NJ  7006    ECONOMIC DEVELOPMENT CORP        NJ
# 80744       NEW YORK    NY     1  EMPIRE ST. CERT. DEVEL CORP        NY
#
#         NAICS  NoEmp  NewExist  CreateJob  RetainedJob  FranchiseCode  \
# 80743       0    191         0         15          176              1
# 80744  611110     23         1          9           23              1
#
#        UrbanRural RevLineCr LowDoc  DisbursementGross  BalanceGross   GrAppv  \
# 80743           0         N      N             621000             0   621000
# 80744           1       NaN      N            1533000             0  1533000
#
#        SBA_Appv  MIS_Status  LoanDisbursedPerCity  LoanPaid  p_MIS_Status  \
# 80743    621000           0               8621403    621000      0.001028
# 80744   1533000           0             940039619   1533000      0.000700
#
#        contrib_City  contrib_State  contrib_Zip  contrib_Bank  \
# 80743      0.033200      -0.396581     0.008223     -0.247561
# 80744     -0.081326      -0.627119    -1.157373     -0.338441
#
#        contrib_BankState  contrib_NAICS  contrib_NoEmp  contrib_NewExist  \
# 80743          -0.612289      -0.127135      -0.745269         -0.281264
# 80744          -0.401730      -0.231680      -0.395546         -0.066454
#
#        contrib_CreateJob  contrib_RetainedJob  contrib_FranchiseCode  \
# 80743          -0.695903            -0.038730              -0.169547
# 80744          -0.452667            -0.005018              -0.038713
#
#        contrib_UrbanRural  contrib_RevLineCr  contrib_LowDoc  \
# 80743           -0.553953          -0.185184       -0.020743
# 80744            0.120501          -0.078562       -0.004777
#
#        contrib_DisbursementGross  contrib_BalanceGross  contrib_GrAppv  \
# 80743                   0.000619                     0       -0.059510
# 80744                  -0.225006                     0        0.359591
#
#        contrib_SBA_Appv  contrib_LoanDisbursedPerCity  contrib_LoanPaid  \
# 80743         -1.299809                      0.009968          0.064243
# 80744         -2.054004                     -0.032092          0.008264
#
#        BiasTerm  r_MIS_Status  r_MIS_Status_abs
# 80743 -0.014561     -0.045346          0.045346
# 80744 -0.014561     -0.037410          0.037410

# %% [markdown]
# **Record 1**

# %%
examine_indiv_reason_codes(correct_test_yhat,80743,include_columns,contrib_columns)
# Out:
# <div id='i987TW40BE8OE4BWYNW23'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.0145612079650163, "outValue": -5.331787343369797, "link": "logit", "featureNames": ["contrib_City", "contrib_State", "contrib_Zip", "contrib_Bank", "contrib_BankState", "contrib_NAICS", "contrib_NoEmp", "contrib_NewExist", "contrib_CreateJob", "contrib_RetainedJob", "contrib_FranchiseCode", "contrib_UrbanRural", "contrib_RevLineCr", "contrib_LowDoc", "contrib_DisbursementGross", "contrib_BalanceGross", "contrib_GrAppv", "contrib_SBA_Appv", "contrib_LoanDisbursedPerCity", "contrib_LoanPaid"], "features": {"0": {"effect": 0.0331997871398925, "value": "WEST CALDWELL"}, "1": {"effect": -0.3965805172920227, "value": "NJ"}, "2": {"effect": 0.008222609758377, "value": 7006.0}, "3": {"effect": -0.247561365365982, "value": "ECONOMIC DEVELOPMENT CORP"}, "4": {"effect": -0.6122889518737793, "value": "NJ"}, "5": {"effect": -0.1271347850561142, "value": 0.0}, "6": {"effect": -0.745268702507019, "value": 191.0}, "7": {"effect": -0.281264066696167, "value": 0.0}, "8": {"effect": -0.6959031224250793, "value": 15.0}, "9": {"effect": -0.0387304611504077, "value": 176.0}, "10": {"effect": -0.169546902179718, "value": 1.0}, "11": {"effect": -0.5539529919624329, "value": 0.0}, "12": {"effect": -0.1851841211318969, "value": "N"}, "13": {"effect": -0.0207427013665437, "value": "N"}, "14": {"effect": 0.0006191616412252188, "value": 621000.0}, "16": {"effect": -0.0595103651285171, "value": 621000.0}, "17": {"effect": -1.2998093366622925, "value": 621000.0}, "18": {"effect": 0.0099678123369812, "value": 8621403.0}, "19": {"effect": 0.064242884516716, "value": 621000.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i987TW40BE8OE4BWYNW23')
#   );
# </script>

# %% [markdown]
# **Record 2**

# %%
examine_indiv_reason_codes(correct_test_yhat,80744,include_columns,contrib_columns)
# Out:
# <div id='i8GIM1GN51NZNQCIKSP80'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.0145612079650163, "outValue": -5.716710288543254, "link": "logit", "featureNames": ["contrib_City", "contrib_State", "contrib_Zip", "contrib_Bank", "contrib_BankState", "contrib_NAICS", "contrib_NoEmp", "contrib_NewExist", "contrib_CreateJob", "contrib_RetainedJob", "contrib_FranchiseCode", "contrib_UrbanRural", "contrib_RevLineCr", "contrib_LowDoc", "contrib_DisbursementGross", "contrib_BalanceGross", "contrib_GrAppv", "contrib_SBA_Appv", "contrib_LoanDisbursedPerCity", "contrib_LoanPaid"], "features": {"0": {"effect": -0.0813261866569519, "value": "NEW YORK"}, "1": {"effect": -0.6271190047264099, "value": "NY"}, "2": {"effect": -1.1573725938796997, "value": 1.0}, "3": {"effect": -0.3384408354759216, "value": "EMPIRE ST. CERT. DEVEL CORP"}, "4": {"effect": -0.4017295241355896, "value": "NY"}, "5": {"effect": -0.2316802740097046, "value": 611110.0}, "6": {"effect": -0.3955459594726562, "value": 23.0}, "7": {"effect": -0.0664540007710456, "value": 1.0}, "8": {"effect": -0.4526667892932892, "value": 9.0}, "9": {"effect": -0.0050184805877506, "value": 23.0}, "10": {"effect": -0.0387125723063945, "value": 1.0}, "11": {"effect": 0.1205012053251266, "value": 1.0}, "12": {"effect": -0.0785617902874946, "value": NaN}, "13": {"effect": -0.0047766072675585, "value": "N"}, "14": {"effect": -0.2250059396028518, "value": 1533000.0}, "16": {"effect": 0.359591394662857, "value": 1533000.0}, "17": {"effect": -2.054003953933716, "value": 1533000.0}, "18": {"effect": -0.0320915766060352, "value": 940039619.0}, "19": {"effect": 0.0082644084468483, "value": 1533000.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i8GIM1GN51NZNQCIKSP80')
#   );
# </script>

# %% [markdown]
# ### 2. Label 0 is identified as 1 ###

# %% [markdown]
# Plotting records with largest negative residuals, when MIS_Status=0 and model predicts high probability of MIS_Status=1.

# %%
test_yhat.tail(2)
# Out:
#                 City State    Zip                    Bank BankState   NAICS  \
# 80743         ELMONT    NY  11003  HSBC BK USA NATL ASSOC        VA  446120
# 80744  SAN FRANCISCO    CA  94132               BBCN BANK        CA  238320
#
#        NoEmp  NewExist  CreateJob  RetainedJob  FranchiseCode  UrbanRural  \
# 80743      4         2          0            4              0           1
# 80744      1         1          0            1              0           1
#
#       RevLineCr LowDoc  DisbursementGross  BalanceGross  GrAppv  SBA_Appv  \
# 80743         Y      N              62500             0   25000     12500
# 80744         N      N              20000             0   20000     17000
#
#        MIS_Status  LoanDisbursedPerCity  LoanPaid  p_MIS_Status  contrib_City  \
# 80743           0              11253880     62500      0.859065      0.008376
# 80744           0             779837894     20000      0.862294     -0.023041
#
#        contrib_State  contrib_Zip  contrib_Bank  contrib_BankState  \
# 80743       0.283358     0.075338      0.190721           1.096626
# 80744       0.111628     0.189348      0.332400           0.652049
#
#        contrib_NAICS  contrib_NoEmp  contrib_NewExist  contrib_CreateJob  \
# 80743       0.070838       0.110436          0.028018          -0.002187
# 80744       0.111352       0.128320         -0.018120           0.000580
#
#        contrib_RetainedJob  contrib_FranchiseCode  contrib_UrbanRural  \
# 80743             0.006244               0.102578            0.465166
# 80744            -0.000738               0.145991            0.527529
#
#        contrib_RevLineCr  contrib_LowDoc  contrib_DisbursementGross  \
# 80743           0.080197        0.016765                   0.192717
# 80744           0.391688        0.026040                   0.124135
#
#        contrib_BalanceGross  contrib_GrAppv  contrib_SBA_Appv  \
# 80743                     0       -0.059521          0.587584
# 80744                     0       -0.090281          0.733865
#
#        contrib_LoanDisbursedPerCity  contrib_LoanPaid  BiasTerm  r_MIS_Status  \
# 80743                      0.006337          0.110227 -0.014561     -1.979623
# 80744                     -0.029499          0.083507 -0.014561     -1.991298
#
#        r_MIS_Status_abs
# 80743          1.979623
# 80744          1.991298

# %% [markdown]
# **Record 1**

# %%
examine_indiv_reason_codes(test_yhat,80743,include_columns,contrib_columns)
# Out:
# <div id='iAK5H1ZA7GULNBSN6C49G'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.0145612079650163, "outValue": 3.35525531321764, "link": "logit", "featureNames": ["contrib_City", "contrib_State", "contrib_Zip", "contrib_Bank", "contrib_BankState", "contrib_NAICS", "contrib_NoEmp", "contrib_NewExist", "contrib_CreateJob", "contrib_RetainedJob", "contrib_FranchiseCode", "contrib_UrbanRural", "contrib_RevLineCr", "contrib_LowDoc", "contrib_DisbursementGross", "contrib_BalanceGross", "contrib_GrAppv", "contrib_SBA_Appv", "contrib_LoanDisbursedPerCity", "contrib_LoanPaid"], "features": {"0": {"effect": 0.0083759510889649, "value": "ELMONT"}, "1": {"effect": 0.2833579182624817, "value": "NY"}, "2": {"effect": 0.0753375217318534, "value": 11003.0}, "3": {"effect": 0.1907207369804382, "value": "HSBC BK USA NATL ASSOC"}, "4": {"effect": 1.096625804901123, "value": "VA"}, "5": {"effect": 0.0708381459116935, "value": 446120.0}, "6": {"effect": 0.1104355603456497, "value": 4.0}, "7": {"effect": 0.0280181691050529, "value": 2.0}, "8": {"effect": -0.0021865987218916, "value": 0.0}, "9": {"effect": 0.0062435041181743, "value": 4.0}, "10": {"effect": 0.1025784835219383, "value": 0.0}, "11": {"effect": 0.4651664793491363, "value": 1.0}, "12": {"effect": 0.0801965296268463, "value": "Y"}, "13": {"effect": 0.0167645588517189, "value": "N"}, "14": {"effect": 0.1927167475223541, "value": 62500.0}, "16": {"effect": -0.0595211945474147, "value": 25000.0}, "17": {"effect": 0.5875837802886963, "value": 12500.0}, "18": {"effect": 0.0063372552394866, "value": 11253880.0}, "19": {"effect": 0.1102271676063537, "value": 62500.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iAK5H1ZA7GULNBSN6C49G')
#   );
# </script>

# %% [markdown]
# **Record 2**

# %%
examine_indiv_reason_codes(test_yhat,80744,include_columns,contrib_columns)
# Out:
# <div id='i8Y80Z2VF3QKH2YHEYAZK'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.0145612079650163, "outValue": 3.3821905547520146, "link": "logit", "featureNames": ["contrib_City", "contrib_State", "contrib_Zip", "contrib_Bank", "contrib_BankState", "contrib_NAICS", "contrib_NoEmp", "contrib_NewExist", "contrib_CreateJob", "contrib_RetainedJob", "contrib_FranchiseCode", "contrib_UrbanRural", "contrib_RevLineCr", "contrib_LowDoc", "contrib_DisbursementGross", "contrib_BalanceGross", "contrib_GrAppv", "contrib_SBA_Appv", "contrib_LoanDisbursedPerCity", "contrib_LoanPaid"], "features": {"0": {"effect": -0.0230414848774671, "value": "SAN FRANCISCO"}, "1": {"effect": 0.111627921462059, "value": "CA"}, "2": {"effect": 0.1893477886915207, "value": 94132.0}, "3": {"effect": 0.3323996961116791, "value": "BBCN BANK"}, "4": {"effect": 0.6520492434501648, "value": "CA"}, "5": {"effect": 0.1113516092300415, "value": 238320.0}, "6": {"effect": 0.1283203959465026, "value": 1.0}, "7": {"effect": -0.0181204117834568, "value": 1.0}, "8": {"effect": 0.0005802320665679872, "value": 0.0}, "9": {"effect": -0.000737527443561703, "value": 1.0}, "10": {"effect": 0.1459909379482269, "value": 0.0}, "11": {"effect": 0.5275285243988037, "value": 1.0}, "12": {"effect": 0.391688197851181, "value": "N"}, "13": {"effect": 0.0260395724326372, "value": "N"}, "14": {"effect": 0.1241351291537284, "value": 20000.0}, "16": {"effect": -0.0902810916304588, "value": 20000.0}, "17": {"effect": 0.73386549949646, "value": 17000.0}, "18": {"effect": -0.0294992998242378, "value": 779837894.0}, "19": {"effect": 0.0835068300366401, "value": 20000.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i8Y80Z2VF3QKH2YHEYAZK')
#   );
# </script>

# %% [markdown]
# ### 3. Label 1 is correctly identified ###

# %%
correct_test_yhat[correct_test_yhat['MIS_Status'] == 1].tail(2)
# Out:
#                   City State    Zip                    Bank BankState   NAICS  \
# 45877  JACKSON HEIGHTS    NY  11372  HSBC BK USA NATL ASSOC        VA  453210
# 51018          MIDLAND    TX  79702       FDIC/WESTERN BANK        TX       0
#
#        NoEmp  NewExist  CreateJob  RetainedJob  FranchiseCode  UrbanRural  \
# 45877      2         1          0            2              0           1
# 51018      1         1       8800         8800              0           0
#
#       RevLineCr LowDoc  DisbursementGross  BalanceGross  GrAppv  SBA_Appv  \
# 45877         Y      N             200000             0  100000     50000
# 51018         N      N             128972             0  130000    111800
#
#        MIS_Status  LoanDisbursedPerCity  LoanPaid  p_MIS_Status  contrib_City  \
# 45877           1              12576687    200000      0.922459      0.022498
# 51018           1              89603730    128972      0.938486      0.003001
#
#        contrib_State  contrib_Zip  contrib_Bank  contrib_BankState  \
# 45877       0.434000     0.137325      0.253545           1.257045
# 51018       0.389081    -0.022642      0.596135           0.406799
#
#        contrib_NAICS  contrib_NoEmp  contrib_NewExist  contrib_CreateJob  \
# 45877       0.159531       0.122473         -0.009275           0.009305
# 51018       0.324448       0.100729         -0.007621           0.538942
#
#        contrib_RetainedJob  contrib_FranchiseCode  contrib_UrbanRural  \
# 45877             0.002388               0.118198            0.523977
# 51018             0.551226               0.508721            0.600760
#
#        contrib_RevLineCr  contrib_LowDoc  contrib_DisbursementGross  \
# 45877           0.072430        0.018109                   0.114773
# 51018           0.010002        0.161348                   0.064283
#
#        contrib_BalanceGross  contrib_GrAppv  contrib_SBA_Appv  \
# 45877                     0        0.048323          0.671989
# 51018                     0       -0.010681          0.005147
#
#        contrib_LoanDisbursedPerCity  contrib_LoanPaid  BiasTerm  r_MIS_Status  \
# 45877                      0.009547          0.072335 -0.014561      0.401776
# 51018                     -0.001737          0.069344 -0.014561      0.356334
#
#        r_MIS_Status_abs
# 45877          0.401776
# 51018          0.356334

# %% [markdown]
# **Record 1**

# %%
examine_indiv_reason_codes(correct_test_yhat,45877,include_columns,contrib_columns)
# Out:
# <div id='iFDHW328QVT6FPD6GJV7S'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.
0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i8L2AOOPT19X17UBAQQU6')
#   );
# </script>

# %% [markdown]
# ### 4. Label 1 is identified as 0 ###

# %% [markdown]
# **Plotting records with largest residuals when MIS_Status=1 and model predicted low probability of MIS_Status=1**

# %%
test_yhat.head(2)
# Out:
#             City State    Zip                            Bank BankState  \
# 0       BILLINGS    MT  59102  WESTERN SECURITY BANK A DIVISI        MT
# 1  BEVERLY HILLS    CA  90211             1ST CENTENNIAL BANK        CA
#
#     NAICS  NoEmp  NewExist  CreateJob  RetainedJob  FranchiseCode  UrbanRural  \
# 0  621310      5         1          0            5              1           1
# 1       0      1         2          0            0              1           1
#
#   RevLineCr LowDoc  DisbursementGross  BalanceGross  GrAppv  SBA_Appv  \
# 0         Y      N             151945             0   40000     20000
# 1         N      N              35000             0   35000     28000
#
#    MIS_Status  LoanDisbursedPerCity  LoanPaid  p_MIS_Status  contrib_City  \
# 0           1             203372653    151945      0.004712     -0.020374
# 1           1              54067149     35000      0.007712     -0.043300
#
#    contrib_State  contrib_Zip  contrib_Bank  contrib_BankState  contrib_NAICS  \
# 0      -0.739418    -0.001571     -0.786001          -1.023354      -0.476850
# 1      -0.118263    -0.097664     -1.465484          -0.457594      -0.746011
#
#    contrib_NoEmp  contrib_NewExist  contrib_CreateJob  contrib_RetainedJob  \
# 0      -0.039283         -0.023369          -0.016351            -0.000895
# 1      -0.047417          0.047956           0.007440            -0.000734
#
#    contrib_FranchiseCode  contrib_UrbanRural  contrib_RevLineCr  \
# 0              -0.033995            0.104894          -0.109433
# 1              -0.092881            0.075790          -0.262389
#
#    contrib_LowDoc  contrib_DisbursementGross  contrib_BalanceGross  \
# 0       -0.000510                  -0.242061                     0
# 1        0.005288                  -0.032064                     0
#
#    contrib_GrAppv  contrib_SBA_Appv  contrib_LoanDisbursedPerCity  \
# 0       -0.275249          0.054953                     -0.013839
# 1       -0.018973          0.021860                     -0.005642
#
#    contrib_LoanPaid  BiasTerm  r_MIS_Status  r_MIS_Status_abs
# 0         -0.147841 -0.014561      3.273391          3.273391
# 1         -0.064883 -0.014561      3.119289          3.119289

# %% [markdown]
# **Record 1**

# %%
examine_indiv_reason_codes(test_yhat,0,include_columns,contrib_columns)
# Out:
# <div id='iIEQBQIXTO9J3TSTF24FB'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.0145612079650163, "outValue": -3.8051063734455965, "link": "logit", "featureNames": ["contrib_City", "contrib_State", "contrib_Zip", "contrib_Bank", "contrib_BankState", "contrib_NAICS", "contrib_NoEmp", "contrib_NewExist", "contrib_CreateJob", "contrib_RetainedJob", "contrib_FranchiseCode", "contrib_UrbanRural", "contrib_RevLineCr", "contrib_LowDoc", "contrib_DisbursementGross", "contrib_BalanceGross", "contrib_GrAppv", "contrib_SB